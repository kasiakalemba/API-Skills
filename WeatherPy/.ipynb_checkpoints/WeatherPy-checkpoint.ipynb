# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV) - ASK GRETEL THIS 
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 594

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build a URL for the OWM API, include a units variable and your API Key 
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Create the variables needed for the data you are interested in
cities = cities

counter = 0
temp = []
lat = []
lon = []
hum = []
cloud = []
wind = []
city_list = []
date =[]
country = []

# Make a loop for each city you will be looking for, appened your empty list for the info you will gather
# Make sure to include an expection for pulled cities that might not show up from CityPy to OWM

for city in cities:
    response = requests.get(query_url + city).json()  
    counter += 1
    
    try:
        city_list.append(city)
        date.append(response['dt'])
        country.append(response['sys']['country'])
        temp.append(response['main']['temp'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        hum.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        print(f"Processing request for: {counter}, {city}")

    except (KeyError):
        city_list.remove(city)
        print("Missing field/result... skipping.")
        pass
# Out:
# Processing request for: 1, oistins
# Processing request for: 2, saint-philippe
# Processing request for: 3, sovetskaya
# Processing request for: 4, hofn
# Missing field/result... skipping.
# Processing request for: 6, porto novo
# Missing field/result... skipping.
# Processing request for: 8, rikitea
# Processing request for: 9, wanlaweyn
# Processing request for: 10, dikson
# Processing request for: 11, mataura
# Processing request for: 12, bud
# Processing request for: 13, mango
# Missing field/result... skipping.
# Processing request for: 15, ushuaia
# Processing request for: 16, hasaki
# Processing request for: 17, albany
# Processing request for: 18, gravdal
# Processing request for: 19, naze
# Processing request for: 20, mahebourg
# Processing request for: 21, hobart
# Processing request for: 22, muskegon heights
# Processing request for: 23, iqaluit
# Processing request for: 24, morrope
# Processing request for: 25, nalut
# Processing request for: 26, cape town
# Processing request for: 27, vaini
# Processing request for: 28, bredasdorp
# Processing request for: 29, atuona
# Processing request for: 30, benjamin constant
# Processing request for: 31, kasangulu
# Missing field/result... skipping.
# Processing request for: 33, east london
# Processing request for: 34, saint george
# Processing request for: 35, constitucion
# Processing request for: 36, busselton
# Processing request for: 37, esperance
# Processing request for: 38, sabang
# Processing request for: 39, yoichi
# Processing request for: 40, codrington
# Missing field/result... skipping.
# Processing request for: 42, jiexiu
# Processing request for: 43, chokurdakh
# Processing request for: 44, norman wells
# Processing request for: 45, punta arenas
# Processing request for: 46, tingo maria
# Processing request for: 47, port elizabeth
# Processing request for: 48, georgetown
# Processing request for: 49, pustoshka
# Processing request for: 50, nikolskoye
# Processing request for: 51, sao filipe
# Processing request for: 52, dolni poustevna
# Processing request for: 53, kutum
# Processing request for: 54, lebu
# Processing request for: 55, chermoz
# Processing request for: 56, torbay
# Processing request for: 57, wanning
# Processing request for: 58, kapaa
# Processing request for: 59, kangavar
# Processing request for: 60, hay river
# Processing request for: 61, new norfolk
# Processing request for: 62, nisia floresta
# Missing field/result... skipping.
# Processing request for: 64, karasburg
# Processing request for: 65, castro
# Processing request for: 66, sicamous
# Processing request for: 67, geraldton
# Processing request for: 68, sandnessjoen
# Processing request for: 69, tasiilaq
# Processing request for: 70, batagay
# Processing request for: 71, omsukchan
# Processing request for: 72, mar del plata
# Processing request for: 73, rypefjord
# Processing request for: 74, paraiso
# Processing request for: 75, union
# Processing request for: 76, whyalla
# Processing request for: 77, hambantota
# Processing request for: 78, urla
# Processing request for: 79, gitega
# Missing field/result... skipping.
# Processing request for: 81, teya
# Processing request for: 82, broken hill
# Processing request for: 83, caravelas
# Processing request for: 84, butaritari
# Processing request for: 85, fuerte olimpo
# Processing request for: 86, vila velha
# Processing request for: 87, andenes
# Processing request for: 88, stornoway
# Processing request for: 89, dingle
# Processing request for: 90, kavieng
# Processing request for: 91, hilo
# Processing request for: 92, provideniya
# Processing request for: 93, mackay
# Processing request for: 94, tarko-sale
# Processing request for: 95, hualmay
# Processing request for: 96, victoria
# Processing request for: 97, edd
# Processing request for: 98, hermanus
# Missing field/result... skipping.
# Processing request for: 100, san juan
# Processing request for: 101, upernavik
# Processing request for: 102, suntar
# Processing request for: 103, samarai
# Processing request for: 104, chimoio
# Processing request for: 105, vila franca do campo
# Processing request for: 106, kodiak
# Processing request for: 107, seoul
# Processing request for: 108, sur
# Processing request for: 109, ponta delgada
# Processing request for: 110, hithadhoo
# Processing request for: 111, yellowknife
# Processing request for: 112, sellye
# Processing request for: 113, ilulissat
# Processing request for: 114, cubuk
# Processing request for: 115, ulverstone
# Missing field/result... skipping.
# Processing request for: 117, lagoa
# Processing request for: 118, avarua
# Processing request for: 119, souillac
# Processing request for: 120, bathsheba
# Processing request for: 121, severo-kurilsk
# Processing request for: 122, hammonton
# Processing request for: 123, dunedin
# Processing request for: 124, kaeo
# Processing request for: 125, takoradi
# Processing request for: 126, kidero
# Processing request for: 127, gualeguay
# Processing request for: 128, honiara
# Processing request for: 129, yanam
# Processing request for: 130, gasa
# Processing request for: 131, maceio
# Missing field/result... skipping.
# Processing request for: 133, tahe
# Processing request for: 134, port lincoln
# Processing request for: 135, tuatapere
# Processing request for: 136, bethel
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing request for: 139, cabo san lucas
# Processing request for: 140, tura
# Processing request for: 141, tuktoyaktuk
# Processing request for: 142, aksu
# Missing field/result... skipping.
# Processing request for: 144, pitea
# Processing request for: 145, mach
# Processing request for: 146, pipar
# Processing request for: 147, arvika
# Missing field/result... skipping.
# Processing request for: 149, batticaloa
# Processing request for: 150, tecoanapa
# Processing request for: 151, estelle
# Processing request for: 152, te anau
# Processing request for: 153, touros
# Processing request for: 154, linxia
# Missing field/result... skipping.
# Processing request for: 156, tupiza
# Processing request for: 157, kirakira
# Processing request for: 158, mount gambier
# Processing request for: 159, belaya gora
# Processing request for: 160, chuy
# Processing request for: 161, aklavik
# Processing request for: 162, sao joao de pirabas
# Processing request for: 163, namatanai
# Processing request for: 164, mount pleasant
# Processing request for: 165, healdsburg
# Processing request for: 166, kahului
# Processing request for: 167, paamiut
# Processing request for: 168, bluff
# Processing request for: 169, raga
# Processing request for: 170, barrow
# Processing request for: 171, glenwood springs
# Processing request for: 172, preveza
# Processing request for: 173, lakatoro
# Processing request for: 174, victor harbor
# Processing request for: 175, shingu
# Processing request for: 176, college
# Processing request for: 177, shimoda
# Processing request for: 178, coahuayana
# Processing request for: 179, nacimiento
# Processing request for: 180, puerto carreno
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing request for: 183, kaitangata
# Processing request for: 184, preobrazheniye
# Processing request for: 185, mino
# Processing request for: 186, mpika
# Processing request for: 187, port alfred
# Processing request for: 188, alofi
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing request for: 191, fortuna
# Processing request for: 192, bengkulu
# Processing request for: 193, churhat
# Processing request for: 194, burnie
# Processing request for: 195, namibe
# Processing request for: 196, pundaguitan
# Processing request for: 197, bulgan
# Missing field/result... skipping.
# Processing request for: 199, kalianget
# Processing request for: 200, petropavlovsk-kamchatskiy
# Processing request for: 201, tiksi
# Processing request for: 202, najran
# Processing request for: 203, thompson
# Processing request for: 204, hefei
# Processing request for: 205, nouakchott
# Processing request for: 206, mandera
# Processing request for: 207, derzhavinsk
# Processing request for: 208, christchurch
# Processing request for: 209, carnarvon
# Missing field/result... skipping.
# Processing request for: 211, kruisfontein
# Processing request for: 212, los llanos de aridane
# Processing request for: 213, khatanga
# Processing request for: 214, cidreira
# Processing request for: 215, fairbanks
# Processing request for: 216, groa
# Processing request for: 217, voyvozh
# Processing request for: 218, turtas
# Processing request for: 219, cumra
# Processing request for: 220, ondjiva
# Processing request for: 221, sisimiut
# Missing field/result... skipping.
# Processing request for: 223, vallenar
# Processing request for: 224, hailey
# Processing request for: 225, avera
# Processing request for: 226, carbonia
# Processing request for: 227, faanui
# Processing request for: 228, shalinskoye
# Processing request for: 229, sipoo
# Processing request for: 230, amapa
# Processing request for: 231, yeppoon
# Processing request for: 232, gazanjyk
# Processing request for: 233, kargopol
# Processing request for: 234, mayo
# Processing request for: 235, ancud
# Processing request for: 236, esil
# Processing request for: 237, karlskrona
# Processing request for: 238, surgut
# Processing request for: 239, cotonou
# Processing request for: 240, isangel
# Processing request for: 241, qaanaaq
# Processing request for: 242, ribeira grande
# Processing request for: 243, urucara
# Processing request for: 244, coihaique
# Processing request for: 245, kyzyl-suu
# Processing request for: 246, nara
# Processing request for: 247, waingapu
# Processing request for: 248, cururupu
# Processing request for: 249, puerto ayora
# Processing request for: 250, ostrovnoy
# Processing request for: 251, saskylakh
# Processing request for: 252, barra
# Processing request for: 253, nicolas bravo
# Processing request for: 254, mineiros
# Processing request for: 255, mingguang
# Processing request for: 256, bandarbeyla
# Processing request for: 257, klamath falls
# Processing request for: 258, inhambane
# Processing request for: 259, arraial do cabo
# Processing request for: 260, bovenden
# Missing field/result... skipping.
# Processing request for: 262, uyemskiy
# Processing request for: 263, lixourion
# Processing request for: 264, alexandru odobescu
# Processing request for: 265, la paz
# Processing request for: 266, charagua
# Processing request for: 267, manacapuru
# Processing request for: 268, san rafael
# Processing request for: 269, batemans bay
# Processing request for: 270, sandakan
# Processing request for: 271, eyl
# Processing request for: 272, cockburn town
# Processing request for: 273, salalah
# Processing request for: 274, urumqi
# Missing field/result... skipping.
# Processing request for: 276, mananara
# Processing request for: 277, oktyabrskiy
# Processing request for: 278, stawell
# Processing request for: 279, puerto leguizamo
# Processing request for: 280, karratha
# Processing request for: 281, zyryanka
# Processing request for: 282, naraini
# Processing request for: 283, asau
# Processing request for: 284, oshkosh
# Processing request for: 285, dovbysh
# Processing request for: 286, tulun
# Processing request for: 287, coolum beach
# Missing field/result... skipping.
# Processing request for: 289, guamal
# Processing request for: 290, sao joao da barra
# Missing field/result... skipping.
# Processing request for: 292, zeven
# Processing request for: 293, angoche
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing request for: 296, port macquarie
# Processing request for: 297, nowy dwor gdanski
# Processing request for: 298, tiznit
# Processing request for: 299, paracuru
# Processing request for: 300, leh
# Missing field/result... skipping.
# Processing request for: 302, sioux lookout
# Missing field/result... skipping.
# Processing request for: 304, nanortalik
# Processing request for: 305, panaba
# Missing field/result... skipping.
# Processing request for: 307, ust-nera
# Processing request for: 308, severnyy
# Processing request for: 309, lata
# Processing request for: 310, sembe
# Processing request for: 311, billings
# Processing request for: 312, davenda
# Processing request for: 313, portland
# Processing request for: 314, dongsheng
# Processing request for: 315, saint-pierre
# Processing request for: 316, denpasar
# Processing request for: 317, rugby
# Processing request for: 318, katsuura
# Processing request for: 319, nikki
# Processing request for: 320, kavaratti
# Processing request for: 321, bilibino
# Processing request for: 322, makakilo city
# Processing request for: 323, vanimo
# Missing field/result... skipping.
# Processing request for: 325, mayor pablo lagerenza
# Processing request for: 326, zlotow
# Processing request for: 327, ulladulla
# Processing request for: 328, komsomolskiy
# Processing request for: 329, cayenne
# Processing request for: 330, singapore
# Processing request for: 331, brae
# Processing request for: 332, new ulm
# Missing field/result... skipping.
# Processing request for: 334, sasolburg
# Processing request for: 335, sahuaripa
# Processing request for: 336, mehamn
# Processing request for: 337, vardo
# Processing request for: 338, chatra
# Processing request for: 339, labuan
# Processing request for: 340, hobyo
# Processing request for: 341, port blair
# Processing request for: 342, taunggyi
# Processing request for: 343, bilma
# Processing request for: 344, lompoc
# Processing request for: 345, parnarama
# Processing request for: 346, narsaq
# Processing request for: 347, marks
# Processing request for: 348, golden
# Processing request for: 349, mandalgovi
# Processing request for: 350, pevek
# Processing request for: 351, tumaco
# Processing request for: 352, chavakkad
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing request for: 356, urgut
# Processing request for: 357, felipe carrillo puerto
# Processing request for: 358, destelbergen
# Processing request for: 359, kushiro
# Processing request for: 360, male
# Processing request for: 361, pangnirtung
# Processing request for: 362, redmond
# Processing request for: 363, sobolevo
# Processing request for: 364, dali
# Processing request for: 365, morro bay
# Processing request for: 366, ilembula
# Missing field/result... skipping.
# Processing request for: 368, itarema
# Processing request for: 369, tilichiki
# Processing request for: 370, talnakh
# Processing request for: 371, qaqortoq
# Processing request for: 372, tonantins
# Processing request for: 373, north bend
# Processing request for: 374, jhunjhunun
# Processing request for: 375, boddam
# Processing request for: 376, egvekinot
# Processing request for: 377, verkhnyaya inta
# Missing field/result... skipping.
# Processing request for: 379, plouzane
# Processing request for: 380, brokopondo
# Processing request for: 381, comodoro rivadavia
# Processing request for: 382, quelimane
# Processing request for: 383, sedalia
# Processing request for: 384, ukiah
# Processing request for: 385, drayton valley
# Processing request for: 386, eydhafushi
# Processing request for: 387, fleury-les-aubrais
# Processing request for: 388, manavalakurichi
# Processing request for: 389, nishihara
# Processing request for: 390, general pico
# Processing request for: 391, puerto narino
# Processing request for: 392, baoying
# Processing request for: 393, lucapa
# Processing request for: 394, hamilton
# Processing request for: 395, mitsamiouli
# Processing request for: 396, la ronge
# Processing request for: 397, honningsvag
# Processing request for: 398, lindi
# Processing request for: 399, alexandria
# Missing field/result... skipping.
# Processing request for: 401, akyab
# Processing request for: 402, marsh harbour
# Processing request for: 403, daru
# Processing request for: 404, luderitz
# Processing request for: 405, ponta do sol
# Processing request for: 406, jamestown
# Processing request for: 407, chumikan
# Processing request for: 408, batagay-alyta
# Processing request for: 409, galle
# Processing request for: 410, grindavik
# Processing request for: 411, matay
# Processing request for: 412, jacksonville
# Missing field/result... skipping.
# Processing request for: 414, labuhan
# Processing request for: 415, talara
# Processing request for: 416, pesochnyy
# Processing request for: 417, bambous virieux
# Processing request for: 418, bac lieu
# Processing request for: 419, kachug
# Processing request for: 420, berbera
# Processing request for: 421, san cristobal
# Processing request for: 422, jacareacanga
# Processing request for: 423, pemba
# Processing request for: 424, dvinskoy
# Processing request for: 425, slave lake
# Processing request for: 426, beringovskiy
# Processing request for: 427, cap malheureux
# Processing request for: 428, aswan
# Processing request for: 429, san jeronimo
# Processing request for: 430, chatellerault
# Processing request for: 431, nordborg
# Processing request for: 432, longyearbyen
# Processing request for: 433, calvinia
# Processing request for: 434, kurumkan
# Missing field/result... skipping.
# Processing request for: 436, airai
# Processing request for: 437, salmas
# Processing request for: 438, port hardy
# Processing request for: 439, champerico
# Processing request for: 440, inuvik
# Processing request for: 441, pacific grove
# Processing request for: 442, srednekolymsk
# Processing request for: 443, clyde river
# Processing request for: 444, sitka
# Processing request for: 445, catabola
# Missing field/result... skipping.
# Processing request for: 447, shenjiamen
# Processing request for: 448, lorengau
# Processing request for: 449, bhatkal
# Processing request for: 450, san patricio
# Processing request for: 451, kysyl-syr
# Processing request for: 452, bemidji
# Processing request for: 453, ramnagar
# Processing request for: 454, marawi
# Processing request for: 455, yar-sale
# Processing request for: 456, tessalit
# Processing request for: 457, chernyshevsk
# Processing request for: 458, isla vista
# Processing request for: 459, offa
# Processing request for: 460, muravlenko
# Processing request for: 461, san buenaventura
# Processing request for: 462, wittmund
# Processing request for: 463, umm kaddadah
# Processing request for: 464, wajima
# Missing field/result... skipping.
# Processing request for: 466, nova olinda do norte
# Processing request for: 467, yongan
# Processing request for: 468, brookings
# Processing request for: 469, kyaiklat
# Processing request for: 470, necochea
# Processing request for: 471, pergine valsugana
# Processing request for: 472, nandurbar
# Processing request for: 473, kokopo
# Processing request for: 474, grants
# Processing request for: 475, petukhovo
# Processing request for: 476, katobu
# Processing request for: 477, hattiesburg
# Processing request for: 478, beyla
# Processing request for: 479, tarancon
# Processing request for: 480, nome
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing request for: 483, white rock
# Processing request for: 484, miri
# Processing request for: 485, nemuro
# Processing request for: 486, zhatay
# Missing field/result... skipping.
# Processing request for: 488, guerrero negro
# Processing request for: 489, kangaatsiaq
# Missing field/result... skipping.
# Processing request for: 491, koutsouras
# Missing field/result... skipping.
# Processing request for: 493, brasilia de minas
# Processing request for: 494, okhotsk
# Processing request for: 495, gizo
# Processing request for: 496, rjukan
# Processing request for: 497, ambon
# Processing request for: 498, arlit
# Processing request for: 499, cherskiy
# Processing request for: 500, bosobolo
# Processing request for: 501, harlingen
# Processing request for: 502, maniitsoq
# Processing request for: 503, dubbo
# Processing request for: 504, khargone
# Processing request for: 505, hearst
# Processing request for: 506, corinto
# Processing request for: 507, sorong
# Processing request for: 508, holbeach
# Processing request for: 509, luganville
# Missing field/result... skipping.
# Processing request for: 511, urdoma
# Processing request for: 512, husavik
# Processing request for: 513, havelock
# Processing request for: 514, meulaboh
# Processing request for: 515, camabatela
# Processing request for: 516, mumbwa
# Processing request for: 517, tateyama
# Processing request for: 518, ixtapa
# Processing request for: 519, prado
# Processing request for: 520, alta floresta
# Processing request for: 521, hailar
# Processing request for: 522, rio grande
# Processing request for: 523, marrakesh
# Processing request for: 524, sangar
# Missing field/result... skipping.
# Processing request for: 526, tinskoy
# Processing request for: 527, noyabrsk
# Processing request for: 528, srinagar
# Processing request for: 529, matara
# Processing request for: 530, paita
# Processing request for: 531, elk plain
# Processing request for: 532, gondar
# Processing request for: 533, neverkino
# Missing field/result... skipping.
# Processing request for: 535, gulf gate estates
# Processing request for: 536, mountain home
# Processing request for: 537, santa rita
# Processing request for: 538, caxito
# Missing field/result... skipping.
# Processing request for: 540, gaoua
# Processing request for: 541, kvareli
# Processing request for: 542, ranong
# Processing request for: 543, benito juarez
# Processing request for: 544, riyadh
# Processing request for: 545, rocha
# Processing request for: 546, palaia fokaia
# Processing request for: 547, verkhnevilyuysk
# Processing request for: 548, suclayin
# Processing request for: 549, moranbah
# Processing request for: 550, hemnesberget
# Processing request for: 551, pirovskoye
# Processing request for: 552, pozega
# Processing request for: 553, flinders
# Processing request for: 554, andros town
# Processing request for: 555, laramie
# Processing request for: 556, binzhou
# Processing request for: 557, teacapan
# Processing request for: 558, umm lajj
# Processing request for: 559, marzuq
# Processing request for: 560, turukhansk
# Processing request for: 561, villamontes
# Processing request for: 562, xiaoshi
# Processing request for: 563, walvis bay
# Processing request for: 564, svetlogorsk
# Processing request for: 565, ossora
# Processing request for: 566, kota belud
# Processing request for: 567, kargasok
# Processing request for: 568, santa cruz de la palma
# Processing request for: 569, canutama
# Processing request for: 570, nabire
# Processing request for: 571, palmer
# Processing request for: 572, acapulco
# Processing request for: 573, whitianga
# Processing request for: 574, dalbandin
# Processing request for: 575, chinsali
# Processing request for: 576, lichuan
# Processing request for: 577, hella
# Processing request for: 578, jega
# Processing request for: 579, chimore
# Processing request for: 580, astoria
# Processing request for: 581, ampanihy
# Missing field/result... skipping.
# Processing request for: 583, boulder city
# Processing request for: 584, rafai
# Processing request for: 585, qasigiannguit
# Processing request for: 586, grafton
# Processing request for: 587, muisne
# Processing request for: 588, dumas
# Missing field/result... skipping.
# Processing request for: 590, ankazoabo
# Processing request for: 591, wellington
# Processing request for: 592, hami
# Processing request for: 593, ternate
# Processing request for: 594, along

# %%
print(len(city_list), len(date), len(country), len(temp), len(lat), len(lon), len(hum), len(cloud), len(wind))
# Out:
# 540 540 540 540 540 540 540 540 540

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# New DataFrame that will hold all the requests from the API 
weather_dict = {
    "city": city_list,
    "country":country,
    "date": date,
    "lat": lat,
    "lon": lon,
    "temp": temp,
    "hum": hum,
    "clouds": cloud,
    "wind": wind
    
}
city_data = pd.DataFrame(weather_dict)
city_data.head()
# Out:
#              city country        date    lat    lon   temp  hum  clouds   wind
# 0         oistins      BB  1586129100  13.07 -59.53  80.60   78      40  13.87
# 1  saint-philippe      RE  1586129100 -21.36  55.77  69.48   78      16   5.82
# 2      sovetskaya      RU  1586129100  44.78  41.17  41.00    3      84  11.01
# 3            hofn      IS  1586129100  64.25 -15.21  45.63   87     100  18.99
# 4      porto novo      BJ  1586129100   6.50   2.60  82.60   80      61   8.55

# %%
# Output to a CSV file so you don't have to make multiple requests from the API 
city_data.to_csv("../output_data/city_data.csv")

# %%
# CSV file ready to be read and random column deleted 
city_df = pd.read_csv("../output_data/city_data.csv")
city_df.keys()
del city_df['Unnamed: 0']
city_df["date"] = pd.to_datetime(city_df['date'], unit='s')
city_df.head()
# Out:
#              city country                date    lat    lon   temp  hum  \
# 0         oistins      BB 2020-04-05 23:25:00  13.07 -59.53  80.60   78
# 1  saint-philippe      RE 2020-04-05 23:25:00 -21.36  55.77  69.48   78
# 2      sovetskaya      RU 2020-04-05 23:25:00  44.78  41.17  41.00    3
# 3            hofn      IS 2020-04-05 23:25:00  64.25 -15.21  45.63   87
# 4      porto novo      BJ 2020-04-05 23:25:00   6.50   2.60  82.60   80
#
#    clouds   wind
# 0      40  13.87
# 1      16   5.82
# 2      84  11.01
# 3     100  18.99
# 4      61   8.55

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Scatter Plots 
plt.scatter(city_df["lat"], city_df["temp"], marker="o")

# Incorporate the other graph properties
plt.title('Temperature vs. Latitude in World Cities')
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig1: Lat vs. Temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_df["lat"], city_df["hum"], marker="o")

# Incorporate the other graph properties
plt.title("Humidity vs. Latitude in World Cities")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig2: Lat vs. Hum.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_df["lat"], city_df["clouds"], marker="o")

# Incorporate the other graph properties
plt.title("Cloudiness vs. Latitude in World Cities")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig3: Lat vs. Clouds.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_df["lat"], city_df["wind"], marker="o")

# Incorporate the other graph properties
plt.title("Wind speed vs. Latitude in World Cities")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig4: Lat vs. Wind.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def regression (x_axis, y_axis, title, xlabel, ylabel):

    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(x_axis,y_axis)
    plt.plot(x_axis,regress_values,"r-")
    
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    plt.tight_layout()
    plt.show()
    
    print(f"The r-squared is: {rvalue**2}")

    return

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df = city_df.loc[city_df["lat"] >=0]
north_df
# Out:
#            city country                date    lat     lon   temp  hum  \
# 0       oistins      BB 2020-04-05 23:25:00  13.07  -59.53  80.60   78
# 2    sovetskaya      RU 2020-04-05 23:25:00  44.78   41.17  41.00    3
# 3          hofn      IS 2020-04-05 23:25:00  64.25  -15.21  45.63   87
# 4    porto novo      BJ 2020-04-05 23:25:00   6.50    2.60  82.60   80
# 6     wanlaweyn      SO 2020-04-05 23:25:00   2.62   44.89  80.22   71
# ..          ...     ...                 ...    ...     ...    ...  ...
# 533      muisne      EC 2020-04-05 23:25:29   0.60  -80.03  80.60   83
# 534       dumas      US 2020-04-05 23:25:29  35.87 -101.97  71.71   33
# 537        hami      CN 2020-04-05 23:25:29  42.80   93.45  52.57   26
# 538     ternate      ID 2020-04-05 23:25:29   0.80  127.40  83.75   70
# 539       along      IN 2020-04-05 23:25:29  28.17   94.77  60.12   49
#
#      clouds   wind
# 0        40  13.87
# 2        84  11.01
# 3       100  18.99
# 4        61   8.55
# 6        21   8.16
# ..      ...    ...
# 533      75   8.05
# 534       1  21.92
# 537      84   1.10
# 538      62   2.33
# 539      93   4.70
#
# [374 rows x 9 columns]

# %%
south_df = city_df.loc[city_df["lat"] <=0]
south_df
# Out:
#                city country                date    lat     lon   temp  hum  \
# 1    saint-philippe      RE 2020-04-05 23:25:00 -21.36   55.77  69.48   78
# 5           rikitea      PF 2020-04-05 23:25:00 -23.12 -134.97  75.34   65
# 8           mataura      NZ 2020-04-05 23:25:01 -46.19  168.86  60.01   87
# 11          ushuaia      AR 2020-04-05 23:20:12 -54.80  -68.30  39.20   80
# 16        mahebourg      MU 2020-04-05 23:25:01 -20.41   57.70  78.08   74
# ..              ...     ...                 ...    ...     ...    ...  ...
# 522        chinsali      ZM 2020-04-05 23:25:28 -10.54   32.08  62.67   64
# 526         chimore      BO 2020-04-05 23:25:29 -16.98  -65.13  75.49   87
# 528        ampanihy      MG 2020-04-05 23:25:29 -24.70   44.75  73.13   59
# 535       ankazoabo      MG 2020-04-05 23:25:29 -22.28   44.52  67.93   77
# 536      wellington      NZ 2020-04-05 23:24:46 -41.29  174.78  63.28   59
#
#      clouds   wind
# 1        16   5.82
# 5        47  10.38
# 8       100   3.00
# 11       40  21.92
# 16       40   9.17
# ..      ...    ...
# 522      61   2.82
# 526      75   2.93
# 528      70   6.15
# 535      23   2.71
# 536      44  13.87
#
# [166 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
regression(north_df["lat"], north_df["temp"],"Temperature vs. Latitude in the Northern Hemisphere","Latitude","Temperature (Celsius)")
# Out:
# The r-squared is: 0.8416431055078494

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
regression(south_df["lat"], south_df["temp"],"Temperature vs. Latitude in the Southern Hemisphere","Latitude","Temperature (Celsius)")
# Out:
# The r-squared is: 0.5854454571379079

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
regression(north_df["lat"], north_df["hum"],"Humidity vs. Latitude in the Northern Hempisphere", "Latitude", "Humidity")
# Out:
# The r-squared is: 0.059964126332257006

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
regression(south_df["lat"], south_df["hum"],"Humidity vs. Latitude in the Southern Hempisphere", "Latitude", "Humidity")
# Out:
# The r-squared is: 0.041318204376839744

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
regression(north_df["lat"], north_df["clouds"],"Cloudiness vs. Latitude in the Northern Hempisphere", "Latitude", "Cloudiness")
# Out:
# The r-squared is: 0.03422132993503855

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
regression(south_df["lat"], south_df["hum"],"Humidity vs. Latitude in the Southern Hempisphere", "Latitude", "Humidity")
# Out:
# The r-squared is: 0.041318204376839744

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
regression(north_df["lat"], north_df["wind"],"Wind Speed vs. Latitude in the Northern Hempisphere", "Latitude", "Wind Speed (mph)")
# Out:
# The r-squared is: 0.07897005583901093

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
regression(south_df["lat"], south_df["wind"],"Wind Speed vs. Latitude in the Southern Hempisphere", "Latitude", "Wind Speed (mph)")
# Out:
# The r-squared is: 0.07308094286371655
