# %% [markdown]
# # WeatherPy

# %% [markdown]
# Observations:
# 1. In the Northern Hemisphere, the higher the latitude shows a negative coorleation to the temperature. This makes sense as the closer you get to the north pole, the colder it gets. Since the southern hemisphere has negative values, there is a positive coorleation between the two, although it is not as strong as it is in the north.
#
# 2. Humidity, cloudiness and wind speed did not display a coorelation to the latitude values. This suggests that these factors are not very location dependent.
#
# 3. The number of values for the Northern Hemisphere from this particular data request was 381 and for the Southern one it was only 177. This makes the southern data more limited for drawing conclutions.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV) - ASK GRETEL THIS 
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build a URL for the OWM API, include a units variable and your API Key 
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Create the variables needed for the data you are interested in
cities = cities

counter = 0
temp = []
lat = []
lon = []
hum = []
cloud = []
wind = []
city_list = []
date =[]
country = []

# Make a loop for each city you will be looking for, appened your empty list for the info you will gather
# Make sure to include an expection for pulled cities that might not show up from CityPy to OWM

for city in cities:
    response = requests.get(query_url + city).json()  
    counter += 1
    
    try:
        city_list.append(city)
        date.append(response['dt'])
        country.append(response['sys']['country'])
        temp.append(response['main']['temp'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        hum.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        print(f"Processing request for: {counter}, {city}")

    except (KeyError):
        city_list.remove(city)
        print("Missing field/result... skipping.")
        pass
# Out:
# Processing request for: 1, gornopravdinsk
# Processing request for: 2, tiznit
# Missing field/result... skipping.
# Processing request for: 4, thompson
# Processing request for: 5, hermanus
# Processing request for: 6, west wendover
# Processing request for: 7, butaritari
# Processing request for: 8, east london
# Processing request for: 9, bluff
# Processing request for: 10, vaini
# Missing field/result... skipping.
# Processing request for: 12, port elizabeth
# Processing request for: 13, albany
# Processing request for: 14, barrow
# Processing request for: 15, hofn
# Processing request for: 16, new norfolk
# Processing request for: 17, ahipara
# Processing request for: 18, anadyr
# Processing request for: 19, kodiak
# Processing request for: 20, punta arenas
# Processing request for: 21, witu
# Processing request for: 22, eyl
# Processing request for: 23, mao
# Processing request for: 24, mataura
# Processing request for: 25, naze
# Processing request for: 26, lompoc
# Processing request for: 27, puerto ayora
# Processing request for: 28, nome
# Processing request for: 29, tuktoyaktuk
# Processing request for: 30, dordrecht
# Processing request for: 31, castro
# Processing request for: 32, avarua
# Processing request for: 33, cape town
# Missing field/result... skipping.
# Processing request for: 35, saskylakh
# Processing request for: 36, araouane
# Processing request for: 37, rikitea
# Processing request for: 38, aripuana
# Processing request for: 39, kapaa
# Processing request for: 40, petropavlovsk-kamchatskiy
# Missing field/result... skipping.
# Processing request for: 42, busselton
# Missing field/result... skipping.
# Processing request for: 44, iqaluit
# Missing field/result... skipping.
# Processing request for: 46, saint george
# Processing request for: 47, ormara
# Processing request for: 48, lebu
# Processing request for: 49, camacari
# Processing request for: 50, hithadhoo
# Processing request for: 51, saldanha
# Processing request for: 52, bengkulu
# Processing request for: 53, jamestown
# Processing request for: 54, berkakit
# Processing request for: 55, souillac
# Processing request for: 56, tarko-sale
# Processing request for: 57, agirish
# Processing request for: 58, banda aceh
# Processing request for: 59, upernavik
# Processing request for: 60, georgetown
# Processing request for: 61, camacha
# Missing field/result... skipping.
# Processing request for: 63, atuona
# Processing request for: 64, geelong
# Processing request for: 65, bowen
# Processing request for: 66, ribeira grande
# Processing request for: 67, senec
# Processing request for: 68, ladushkin
# Processing request for: 69, utete
# Processing request for: 70, marfino
# Processing request for: 71, pahalgam
# Processing request for: 72, yellowknife
# Processing request for: 73, pisco
# Processing request for: 74, san patricio
# Processing request for: 75, archidona
# Processing request for: 76, sambava
# Processing request for: 77, prieska
# Processing request for: 78, chokurdakh
# Processing request for: 79, port lincoln
# Processing request for: 80, dikson
# Missing field/result... skipping.
# Processing request for: 82, kahului
# Processing request for: 83, fujin
# Missing field/result... skipping.
# Processing request for: 85, bredasdorp
# Processing request for: 86, port alfred
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing request for: 89, huarmey
# Processing request for: 90, irtyshskiy
# Processing request for: 91, ushuaia
# Processing request for: 92, ashland
# Processing request for: 93, hit
# Processing request for: 94, atar
# Processing request for: 95, havre-saint-pierre
# Processing request for: 96, yarada
# Processing request for: 97, vandalur
# Processing request for: 98, robe
# Processing request for: 99, sturgis
# Processing request for: 100, comodoro rivadavia
# Processing request for: 101, qaanaaq
# Processing request for: 102, hwange
# Processing request for: 103, avera
# Processing request for: 104, hobart
# Processing request for: 105, antofagasta
# Processing request for: 106, padang
# Missing field/result... skipping.
# Processing request for: 108, coihaique
# Missing field/result... skipping.
# Processing request for: 110, hilo
# Processing request for: 111, nokaneng
# Processing request for: 112, chambas
# Processing request for: 113, alofi
# Processing request for: 114, richards bay
# Processing request for: 115, ancud
# Processing request for: 116, korla
# Processing request for: 117, cocobeach
# Processing request for: 118, maumere
# Processing request for: 119, guanare
# Processing request for: 120, horstel
# Processing request for: 121, takoradi
# Processing request for: 122, vila franca do campo
# Processing request for: 123, lahaina
# Processing request for: 124, santa teresa
# Processing request for: 125, leningradskiy
# Processing request for: 126, carnarvon
# Processing request for: 127, nikolskoye
# Processing request for: 128, lagoa
# Processing request for: 129, kruisfontein
# Processing request for: 130, mackay
# Processing request for: 131, oranjemund
# Processing request for: 132, nortelandia
# Processing request for: 133, crotone
# Processing request for: 134, lata
# Processing request for: 135, margate
# Processing request for: 136, saint-philippe
# Processing request for: 137, shepsi
# Processing request for: 138, chumikan
# Processing request for: 139, ponta delgada
# Processing request for: 140, ghanzi
# Processing request for: 141, college
# Processing request for: 142, the valley
# Processing request for: 143, pueblo
# Processing request for: 144, tasiilaq
# Processing request for: 145, eureka
# Processing request for: 146, bilibino
# Processing request for: 147, kijang
# Processing request for: 148, ocho rios
# Processing request for: 149, lethem
# Processing request for: 150, yarim
# Processing request for: 151, manbij
# Processing request for: 152, nola
# Processing request for: 153, nouadhibou
# Processing request for: 154, olafsvik
# Processing request for: 155, airai
# Processing request for: 156, sistranda
# Processing request for: 157, yulara
# Processing request for: 158, alpena
# Processing request for: 159, pinega
# Processing request for: 160, severo-kurilsk
# Processing request for: 161, bambous virieux
# Processing request for: 162, khatanga
# Processing request for: 163, tukrah
# Processing request for: 164, vilhena
# Processing request for: 165, fengrun
# Processing request for: 166, mjolby
# Missing field/result... skipping.
# Processing request for: 168, petropavl
# Missing field/result... skipping.
# Processing request for: 170, coquimbo
# Processing request for: 171, termoli
# Processing request for: 172, birin
# Processing request for: 173, mar del plata
# Processing request for: 174, bethel
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing request for: 177, cidreira
# Processing request for: 178, celestun
# Processing request for: 179, nobres
# Processing request for: 180, miyako
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing request for: 183, conceicao do araguaia
# Processing request for: 184, lewisporte
# Processing request for: 185, vanimo
# Processing request for: 186, axim
# Processing request for: 187, texarkana
# Processing request for: 188, faya
# Missing field/result... skipping.
# Processing request for: 190, lop buri
# Processing request for: 191, dothan
# Processing request for: 192, saint-francois
# Processing request for: 193, surt
# Processing request for: 194, pyinmana
# Processing request for: 195, lorengau
# Processing request for: 196, santa marta
# Processing request for: 197, namatanai
# Processing request for: 198, sitka
# Processing request for: 199, ust-nera
# Processing request for: 200, kavaratti
# Processing request for: 201, pacific grove
# Processing request for: 202, touros
# Processing request for: 203, ostrovnoy
# Processing request for: 204, omboue
# Processing request for: 205, wewak
# Processing request for: 206, tallahassee
# Processing request for: 207, esqueda
# Processing request for: 208, luderitz
# Processing request for: 209, lavrentiya
# Processing request for: 210, longyearbyen
# Processing request for: 211, booue
# Processing request for: 212, cabedelo
# Processing request for: 213, puri
# Processing request for: 214, cherskiy
# Processing request for: 215, lasa
# Processing request for: 216, waipawa
# Processing request for: 217, soledade
# Processing request for: 218, tigil
# Processing request for: 219, kahta
# Processing request for: 220, massakory
# Processing request for: 221, thinadhoo
# Processing request for: 222, geraldton
# Processing request for: 223, cockburn town
# Processing request for: 224, oistins
# Processing request for: 225, missoula
# Processing request for: 226, narsaq
# Processing request for: 227, pavilosta
# Processing request for: 228, adrar
# Processing request for: 229, grants pass
# Processing request for: 230, palmer
# Processing request for: 231, taoudenni
# Processing request for: 232, bahia de caraquez
# Processing request for: 233, fortuna
# Processing request for: 234, vega de alatorre
# Processing request for: 235, fairbanks
# Processing request for: 236, mnogovershinnyy
# Processing request for: 237, trelew
# Processing request for: 238, noumea
# Processing request for: 239, havoysund
# Processing request for: 240, ondjiva
# Processing request for: 241, oktyabrskoye
# Processing request for: 242, mahajanga
# Processing request for: 243, byron bay
# Processing request for: 244, matane
# Processing request for: 245, gizo
# Processing request for: 246, puerto cabello
# Processing request for: 247, norman wells
# Processing request for: 248, hamilton
# Processing request for: 249, raga
# Processing request for: 250, katsuura
# Processing request for: 251, goderich
# Processing request for: 252, klaksvik
# Processing request for: 253, codrington
# Processing request for: 254, severo-yeniseyskiy
# Processing request for: 255, annau
# Processing request for: 256, dawei
# Processing request for: 257, si sa ket
# Processing request for: 258, bayan
# Processing request for: 259, mahebourg
# Processing request for: 260, arraial do cabo
# Processing request for: 261, puerto penasco
# Processing request for: 262, tiksi
# Processing request for: 263, udachnyy
# Processing request for: 264, pevek
# Processing request for: 265, san quintin
# Processing request for: 266, senanga
# Processing request for: 267, druzhba
# Processing request for: 268, ust-koksa
# Processing request for: 269, kulu
# Processing request for: 270, nuuk
# Processing request for: 271, paungde
# Missing field/result... skipping.
# Processing request for: 273, nenjiang
# Processing request for: 274, alice springs
# Processing request for: 275, namibe
# Processing request for: 276, nyagan
# Processing request for: 277, san luis
# Processing request for: 278, faanui
# Processing request for: 279, det udom
# Processing request for: 280, tucumcari
# Processing request for: 281, sal rei
# Processing request for: 282, pingliang
# Processing request for: 283, puerto leguizamo
# Processing request for: 284, ixtapa
# Processing request for: 285, tuatapere
# Processing request for: 286, nevel
# Processing request for: 287, kachug
# Processing request for: 288, santa cruz
# Processing request for: 289, taldan
# Processing request for: 290, chuy
# Processing request for: 291, guiglo
# Processing request for: 292, condado
# Missing field/result... skipping.
# Processing request for: 294, dingle
# Missing field/result... skipping.
# Processing request for: 296, palora
# Processing request for: 297, irbeyskoye
# Processing request for: 298, nanortalik
# Missing field/result... skipping.
# Processing request for: 300, kondinskoye
# Processing request for: 301, wanning
# Processing request for: 302, port blair
# Processing request for: 303, ruidoso
# Processing request for: 304, san carlos de bariloche
# Processing request for: 305, ambon
# Processing request for: 306, baruun-urt
# Processing request for: 307, dzhida
# Processing request for: 308, talcahuano
# Processing request for: 309, robertsport
# Processing request for: 310, radzyn podlaski
# Processing request for: 311, rumoi
# Missing field/result... skipping.
# Processing request for: 313, kazerun
# Processing request for: 314, sevsk
# Processing request for: 315, ko samui
# Processing request for: 316, sialkot
# Processing request for: 317, saint anthony
# Missing field/result... skipping.
# Processing request for: 319, hauterive
# Processing request for: 320, kavieng
# Missing field/result... skipping.
# Processing request for: 322, zinder
# Processing request for: 323, chalus
# Processing request for: 324, juybar
# Processing request for: 325, port augusta
# Processing request for: 326, harbour breton
# Processing request for: 327, husavik
# Processing request for: 328, plettenberg bay
# Processing request for: 329, travesia
# Processing request for: 330, seoul
# Processing request for: 331, bosaso
# Processing request for: 332, broken hill
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing request for: 335, isangel
# Processing request for: 336, puerto escondido
# Processing request for: 337, deputatskiy
# Processing request for: 338, ornskoldsvik
# Processing request for: 339, kaitangata
# Processing request for: 340, torbay
# Processing request for: 341, marystown
# Processing request for: 342, tual
# Processing request for: 343, ludvika
# Processing request for: 344, hasaki
# Processing request for: 345, zorritos
# Processing request for: 346, pandamatenga
# Processing request for: 347, yar-sale
# Processing request for: 348, beloha
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing request for: 351, la ronge
# Processing request for: 352, victoria
# Processing request for: 353, ahuimanu
# Missing field/result... skipping.
# Processing request for: 355, juneau
# Processing request for: 356, paita
# Processing request for: 357, kosino
# Processing request for: 358, grajau
# Processing request for: 359, nioro
# Processing request for: 360, krasnoselkup
# Processing request for: 361, wawa
# Processing request for: 362, portsmouth
# Processing request for: 363, jining
# Processing request for: 364, vostok
# Processing request for: 365, northam
# Processing request for: 366, bathsheba
# Processing request for: 367, te anau
# Processing request for: 368, cabo san lucas
# Processing request for: 369, nemuro
# Processing request for: 370, sibolga
# Processing request for: 371, machilipatnam
# Processing request for: 372, phan thiet
# Processing request for: 373, dubrovnik
# Processing request for: 374, constitucion
# Processing request for: 375, saint-augustin
# Processing request for: 376, krompachy
# Processing request for: 377, bijie
# Processing request for: 378, rio gallegos
# Missing field/result... skipping.
# Processing request for: 380, srandakan
# Processing request for: 381, denpasar
# Processing request for: 382, veraval
# Processing request for: 383, tateyama
# Processing request for: 384, papar
# Processing request for: 385, mayya
# Processing request for: 386, guerrero negro
# Processing request for: 387, batouri
# Processing request for: 388, ishigaki
# Processing request for: 389, lago da pedra
# Processing request for: 390, baykit
# Processing request for: 391, boddam
# Processing request for: 392, caravelas
# Processing request for: 393, asyut
# Processing request for: 394, srednekolymsk
# Processing request for: 395, redmond
# Processing request for: 396, broome
# Processing request for: 397, samarai
# Processing request for: 398, vila
# Processing request for: 399, mehamn
# Processing request for: 400, sangar
# Processing request for: 401, outjo
# Missing field/result... skipping.
# Processing request for: 403, harper
# Processing request for: 404, gamboma
# Processing request for: 405, maxixe
# Processing request for: 406, karatuzskoye
# Processing request for: 407, burnie
# Processing request for: 408, san juan
# Missing field/result... skipping.
# Processing request for: 410, three hills
# Processing request for: 411, batagay-alyta
# Processing request for: 412, aksu
# Processing request for: 413, cayenne
# Processing request for: 414, pemangkat
# Processing request for: 415, hami
# Processing request for: 416, sabang
# Processing request for: 417, ponta do sol
# Processing request for: 418, san pablo de las salinas
# Processing request for: 419, menongue
# Processing request for: 420, belmonte
# Processing request for: 421, brive-la-gaillarde
# Processing request for: 422, forres
# Processing request for: 423, kismayo
# Processing request for: 424, itarema
# Processing request for: 425, pervomayskoye
# Processing request for: 426, aklavik
# Processing request for: 427, camacupa
# Processing request for: 428, taksimo
# Processing request for: 429, beirut
# Processing request for: 430, mana
# Processing request for: 431, ramygala
# Processing request for: 432, havelock
# Processing request for: 433, berlevag
# Processing request for: 434, gat
# Processing request for: 435, stornoway
# Processing request for: 436, almeirim
# Processing request for: 437, atasu
# Processing request for: 438, dolores
# Processing request for: 439, valdivia
# Missing field/result... skipping.
# Processing request for: 441, chippewa falls
# Processing request for: 442, tautira
# Processing request for: 443, segezha
# Processing request for: 444, hovd
# Processing request for: 445, provideniya
# Processing request for: 446, acapulco
# Processing request for: 447, barillas
# Processing request for: 448, labrea
# Processing request for: 449, camapua
# Processing request for: 450, bo phloi
# Missing field/result... skipping.
# Processing request for: 452, alyangula
# Processing request for: 453, esperance
# Processing request for: 454, xining
# Processing request for: 455, atbasar
# Processing request for: 456, zelenoborskiy
# Processing request for: 457, dwarka
# Processing request for: 458, sorland
# Processing request for: 459, kidal
# Processing request for: 460, half moon bay
# Processing request for: 461, mantua
# Processing request for: 462, fort-shevchenko
# Processing request for: 463, sao filipe
# Processing request for: 464, kysyl-syr
# Processing request for: 465, evensk
# Processing request for: 466, paamiut
# Processing request for: 467, peru
# Processing request for: 468, egvekinot
# Processing request for: 469, portree
# Processing request for: 470, pochutla
# Processing request for: 471, whitianga
# Processing request for: 472, saint-joseph
# Processing request for: 473, lahij
# Processing request for: 474, mont-dore
# Processing request for: 475, boulsa
# Processing request for: 476, kirkenaer
# Processing request for: 477, laguna
# Processing request for: 478, beyneu
# Processing request for: 479, rochester
# Missing field/result... skipping.
# Processing request for: 481, kirakira
# Processing request for: 482, birao
# Processing request for: 483, winneba
# Processing request for: 484, atherton
# Processing request for: 485, anton lizardo
# Processing request for: 486, sao joao da barra
# Processing request for: 487, caucaia
# Processing request for: 488, jacareacanga
# Processing request for: 489, hanmer springs
# Processing request for: 490, isla vista
# Processing request for: 491, kununurra
# Processing request for: 492, vardo
# Processing request for: 493, pokhara
# Processing request for: 494, linxia
# Processing request for: 495, nalut
# Processing request for: 496, caconda
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing request for: 499, north bend
# Processing request for: 500, yauya
# Processing request for: 501, sayyan
# Processing request for: 502, champerico
# Processing request for: 503, quatre cocos
# Processing request for: 504, miles city
# Processing request for: 505, chara
# Processing request for: 506, dandong
# Processing request for: 507, grand-lahou
# Processing request for: 508, roebourne
# Processing request for: 509, lynn haven
# Processing request for: 510, matelica
# Processing request for: 511, kankan
# Processing request for: 512, gamba
# Processing request for: 513, morant bay
# Processing request for: 514, falam
# Processing request for: 515, sioux lookout
# Processing request for: 516, hualmay
# Processing request for: 517, riyadh
# Processing request for: 518, majene
# Processing request for: 519, bell ville
# Processing request for: 520, vestmannaeyjar
# Processing request for: 521, kemin
# Processing request for: 522, talavera de la reina
# Processing request for: 523, talnakh
# Processing request for: 524, espanola
# Processing request for: 525, calabaca
# Processing request for: 526, chifeng
# Processing request for: 527, alice town
# Processing request for: 528, pakhtakoron
# Processing request for: 529, bilma
# Processing request for: 530, ust-kuyga
# Processing request for: 531, zeya
# Processing request for: 532, coffs harbour
# Processing request for: 533, taguatinga
# Processing request for: 534, kristiinankaupunki
# Processing request for: 535, mvuma
# Processing request for: 536, ulety
# Processing request for: 537, eagle pass
# Processing request for: 538, wellington
# Processing request for: 539, grand gaube
# Processing request for: 540, stokmarknes
# Processing request for: 541, dabakala
# Processing request for: 542, svetlogorsk
# Missing field/result... skipping.
# Processing request for: 544, santa ana
# Processing request for: 545, bambanglipuro
# Processing request for: 546, necochea
# Processing request for: 547, melendugno
# Processing request for: 548, ilulissat
# Processing request for: 549, mount gambier
# Processing request for: 550, prudyanka
# Processing request for: 551, ambovombe
# Processing request for: 552, palasa
# Processing request for: 553, zaoyang
# Processing request for: 554, wattegama
# Processing request for: 555, vallenar
# Processing request for: 556, bac lieu
# Processing request for: 557, rock springs
# Processing request for: 558, hobyo
# Processing request for: 559, qaqortoq
# Processing request for: 560, migori
# Processing request for: 561, ust-ishim
# Processing request for: 562, kiunga
# Processing request for: 563, liepaja
# Processing request for: 564, nishihara
# Processing request for: 565, newcastle
# Processing request for: 566, ketchikan
# Processing request for: 567, san cristobal
# Processing request for: 568, maceio
# Processing request for: 569, obzor
# Processing request for: 570, jerome
# Processing request for: 571, kaeo
# Processing request for: 572, erzin
# Processing request for: 573, fort abbas
# Missing field/result... skipping.
# Processing request for: 575, mayumba
# Processing request for: 576, henties bay
# Processing request for: 577, radstadt
# Processing request for: 578, yaan
# Processing request for: 579, sur
# Processing request for: 580, honiara
# Processing request for: 581, marzuq
# Processing request for: 582, obigarm
# Processing request for: 583, port hedland
# Processing request for: 584, san jeronimo
# Processing request for: 585, porto novo
# Processing request for: 586, lai
# Processing request for: 587, portland
# Processing request for: 588, ayios nikolaos
# Processing request for: 589, dubbo
# Processing request for: 590, warrnambool
# Processing request for: 591, cavalcante
# Missing field/result... skipping.
# Processing request for: 593, lichtenburg
# Processing request for: 594, aswan
# Processing request for: 595, yinchuan
# Processing request for: 596, karasjok
# Processing request for: 597, mizdah
# Processing request for: 598, hambantota
# Processing request for: 599, kyzyl-suu
# Processing request for: 600, xingyi
# Processing request for: 601, emba

# %%
# Making sure all the columns have an even amount of data to avoid future errors
print(len(city_list), len(date), len(country), len(temp), len(lat), len(lon), len(hum), len(cloud), len(wind))
# Out:
# 558 558 558 558 558 558 558 558 558

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# New DataFrame that will hold all the requests from the API 
weather_dict = {
    "city": city_list,
    "country":country,
    "date": date,
    "lat": lat,
    "lon": lon,
    "temp": temp,
    "hum": hum,
    "clouds": cloud,
    "wind": wind
    
}
city_data = pd.DataFrame(weather_dict)
city_data.head()
# Out:
#              city country        date    lat     lon   temp  hum  clouds  \
# 0  gornopravdinsk      RU  1586629500  60.05   69.90  35.87   87       0
# 1          tiznit      MA  1586629201  29.58   -9.50  62.62   60     100
# 2        thompson      CA  1586629501  55.74  -97.86  26.60   68      90
# 3        hermanus      ZA  1586629501 -34.42   19.23  67.75   76     100
# 4   west wendover      US  1586629501  40.74 -114.07  66.20   24       1
#
#     wind
# 0   6.51
# 1   7.76
# 2   5.82
# 3   3.00
# 4  16.11

# %%
# Output to a CSV file so you don't have to make multiple requests from the API 
city_data.to_csv("../output_data/city_data.csv")

# %%
# CSV file ready to be read and random column deleted 
city_df = pd.read_csv("../output_data/city_data.csv")
city_df.keys()
del city_df['Unnamed: 0']
city_df["date"] = pd.to_datetime(city_df['date'], unit='s')
city_df.head()
# Out:
#              city country                date    lat     lon   temp  hum  \
# 0  gornopravdinsk      RU 2020-04-11 18:25:00  60.05   69.90  35.87   87
# 1          tiznit      MA 2020-04-11 18:20:01  29.58   -9.50  62.62   60
# 2        thompson      CA 2020-04-11 18:25:01  55.74  -97.86  26.60   68
# 3        hermanus      ZA 2020-04-11 18:25:01 -34.42   19.23  67.75   76
# 4   west wendover      US 2020-04-11 18:25:01  40.74 -114.07  66.20   24
#
#    clouds   wind
# 0       0   6.51
# 1     100   7.76
# 2      90   5.82
# 3     100   3.00
# 4       1  16.11

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Scatter Plots 
date = city_df.iloc[3,2]

plt.scatter(city_df["lat"], city_df["temp"], marker="o")

# Incorporate the other graph properties 
plt.title(f'Temperature vs. Latitude in World Cities' + " " + str(date) )
plt.ylabel("Temperature (Far)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig1: Lat vs. Temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_df["lat"], city_df["hum"], marker="o")

# Humidity Plot 
plt.title("Humidity vs. Latitude in World Cities" + " " + str(date))
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig2: Lat vs. Hum.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_df["lat"], city_df["clouds"], marker="o")

# Cloudiness Scatter Plot 
plt.title("Cloudiness vs. Latitude in World Cities" +  " " + str(date))
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig3: Lat vs. Clouds.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_df["lat"], city_df["wind"], marker="o")

# Wind speed scatter plot 
plt.title("Wind speed vs. Latitude in World Cities" +  " " + str(date))
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig4: Lat vs. Wind.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def regression (x_axis, y_axis, title, xlabel, ylabel):

    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(x_axis,y_axis)
    plt.plot(x_axis,regress_values,"r-")
    
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    plt.tight_layout()
    plt.show()
    
    print(f"The r-squared is: {rvalue**2}")

    return

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df = city_df.loc[city_df["lat"] >=0]
north_df
# Out:
#                city country                date    lat     lon   temp  hum  \
# 0    gornopravdinsk      RU 2020-04-11 18:25:00  60.05   69.90  35.87   87
# 1            tiznit      MA 2020-04-11 18:20:01  29.58   -9.50  62.62   60
# 2          thompson      CA 2020-04-11 18:25:01  55.74  -97.86  26.60   68
# 4     west wendover      US 2020-04-11 18:25:01  40.74 -114.07  66.20   24
# 5        butaritari      KI 2020-04-11 18:25:01   3.07  172.79  83.77   76
# ..              ...     ...                 ...    ...     ...    ...  ...
# 553          mizdah      LY 2020-04-11 18:25:39  31.45   12.98  62.80   42
# 554      hambantota      LK 2020-04-11 18:25:39   6.12   81.12  82.18   79
# 555       kyzyl-suu      KG 2020-04-11 18:25:39  42.34   78.00  45.00   30
# 556          xingyi      CN 2020-04-11 18:25:39  24.19  102.82  55.80   49
# 557            emba      KZ 2020-04-11 18:25:39  48.83   58.14  44.51   53
#
#      clouds   wind
# 0         0   6.51
# 1       100   7.76
# 2        90   5.82
# 4         1  16.11
# 5        78  12.77
# ..      ...    ...
# 553      14  13.76
# 554      16  11.61
# 555      98   3.20
# 556      57   6.04
# 557      33   9.80
#
# [381 rows x 9 columns]

# %%
south_df = city_df.loc[city_df["lat"] <=0]
south_df
# Out:
#                city country                date    lat     lon   temp  hum  \
# 3          hermanus      ZA 2020-04-11 18:25:01 -34.42   19.23  67.75   76
# 6       east london      ZA 2020-04-11 18:24:27 -33.02   27.91  74.05   74
# 7             bluff      NZ 2020-04-11 18:25:01 -46.60  168.33  53.01   75
# 8             vaini      TO 2020-04-11 18:25:01 -21.20 -175.20  64.40   93
# 9    port elizabeth      ZA 2020-04-11 18:25:02 -33.92   25.57  59.00   72
# ..              ...     ...                 ...    ...     ...    ...  ...
# 541    san jeronimo      PE 2020-04-11 18:25:38 -11.95  -75.28  63.32   18
# 546           dubbo      AU 2020-04-11 18:25:38 -32.25  148.62  46.40   81
# 547     warrnambool      AU 2020-04-11 18:25:38 -38.38  142.48  52.00   78
# 548      cavalcante      BR 2020-04-11 18:25:38 -13.80  -47.46  80.26   56
# 549     lichtenburg      ZA 2020-04-11 18:25:04 -26.15   26.16  63.68   29
#
#      clouds   wind
# 3       100   3.00
# 6       100  12.88
# 7       100   3.00
# 8        20   2.24
# 9       100   3.36
# ..      ...    ...
# 541      65   6.62
# 546       4   9.17
# 547      62  15.30
# 548      83   4.68
# 549      12   3.87
#
# [177 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
regression(north_df["lat"], north_df["temp"],"Temperature vs. Latitude in the Northern Hemisphere","Latitude","Temperature (Far)")
# Out:
# The r-squared is: 0.8071461179267692

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
regression(south_df["lat"], south_df["temp"],"Temperature vs. Latitude in the Southern Hemisphere","Latitude","Temperature (Celsius)")
# Out:
# The r-squared is: 0.6027798113987841

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
regression(north_df["lat"], north_df["hum"],"Humidity vs. Latitude in the Northern Hempisphere", "Latitude", "Humidity")
# Out:
# The r-squared is: 0.0848140833703218

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
regression(south_df["lat"], south_df["hum"],"Humidity vs. Latitude in the Southern Hempisphere", "Latitude", "Humidity")
# Out:
# The r-squared is: 0.033161616676625566

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
regression(north_df["lat"], north_df["clouds"],"Cloudiness vs. Latitude in the Northern Hempisphere", "Latitude", "Cloudiness")
# Out:
# The r-squared is: 0.061774182000621396

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
regression(south_df["lat"], south_df["hum"],"Humidity vs. Latitude in the Southern Hempisphere", "Latitude", "Humidity")
# Out:
# The r-squared is: 0.033161616676625566

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
regression(north_df["lat"], north_df["wind"],"Wind Speed vs. Latitude in the Northern Hempisphere", "Latitude", "Wind Speed (mph)")
# Out:
# The r-squared is: 0.002994575549146532

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
regression(south_df["lat"], south_df["wind"],"Wind Speed vs. Latitude in the Southern Hempisphere", "Latitude", "Wind Speed (mph)")
# Out:
# The r-squared is: 0.2103629986134329
